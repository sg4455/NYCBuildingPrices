# %% [markdown]
# # NYC Real Estate Price Prediction
#
# ## Objective
#
# We will predict the real estate price to help the people buy and sell at a reasonable price.

# %% [markdown]
# ## Business problems we will solve:
#
# Lack of appropriate price information of real estate in NYC for individual seller and
# buyer.
#
# What type of building a real estate developer should build for the most add-value.
#
#
# **The Use Scenario:**
#
# When one wants to sell the real estate, they can use the model we create and add some variables (location, year, area, etc) to get the appropriate prediction price.
#
# **Data mining and modeling**
#
# Price is a target variable, and we will use supervised machine learning with cross-validation to find out influential variables.
#
#
# **Source of data**
# NYC government official data.
#
# https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page

# %% [markdown]
# # Data Understanding

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
def load_data():
    df_mh=pd.read_excel("rollingsales_manhattan.xls",skiprows=4)
    df_mh["AREA"]="MH"
    df_bx=pd.read_excel("rollingsales_bronx.xls",skiprows=4)
    df_bx["AREA"]="BX"
    df=pd.concat([df_mh,df_bx])
    df.columns = df.columns.str.replace(' ', '_')
    df=df.drop(columns=['EASE-MENT'])# all the values in this column is nan.
    df['not_apartment']=df['APARTMENT_NUMBER'].isna()# ture: it is not an apartment. false: it is an apartment.
    df=df.drop(columns=['APARTMENT_NUMBER','ADDRESS','BUILDING_CLASS_AT_PRESENT'])
    
    df=df.dropna()
    return df

# %% [markdown]
# Here is how our data looks like:

# %%
df=load_data()
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD  BUILDING_CLASS_CATEGORY TAX_CLASS_AT_PRESENT  \
# 0        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 1        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 2        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 3        1  ALPHABET CITY  02 TWO FAMILY DWELLINGS                    1
# 4        1  ALPHABET CITY  02 TWO FAMILY DWELLINGS                    1
#
#    BLOCK  LOT  ZIP_CODE  RESIDENTIAL_UNITS  COMMERCIAL_UNITS  TOTAL_UNITS  \
# 0    390   61   10009.0                1.0               0.0          1.0
# 1    390   61   10009.0                1.0               0.0          1.0
# 2    400   19   10009.0                1.0               0.0          1.0
# 3    390   35   10009.0                2.0               0.0          2.0
# 4    404    1   10009.0                2.0               0.0          2.0
#
#    LAND_SQUARE_FEET  GROSS_SQUARE_FEET  YEAR_BUILT  TAX_CLASS_AT_TIME_OF_SALE  \
# 0             987.0             2183.0      1860.0                          1
# 1             987.0             2183.0      1860.0                          1
# 2            1883.0             5200.0      1900.0                          1
# 3            1218.0             4764.0      1899.0                          1
# 4            1510.0             4520.0      1900.0                          1
#
#   BUILDING_CLASS_AT_TIME_OF_SALE  SALE_PRICE  SALE_DATE AREA  not_apartment
# 0                             A4     4844809 2018-05-22   MH           True
# 1                             A4           0 2018-05-23   MH           True
# 2                             A4     6100000 2018-12-03   MH           True
# 3                             B1           0 2018-04-25   MH           True
# 4                             B9           0 2018-11-29   MH           True

# %% [markdown]
# Our target variable is SALE_PRICE.
# So, let's take a look of the distribution.

# %%
df["SALE_PRICE"].describe()
# Out:
# count    2.443900e+04
# mean     2.406437e+06
# std      2.344970e+07
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      5.800000e+05
# 75%      1.340045e+06
# max      2.397502e+09
# Name: SALE_PRICE, dtype: float64

# %%
df["SALE_PRICE"] = df["SALE_PRICE"].replace(0, np.NaN)
df["SALE_PRICE"].describe()
# Out:
# count    1.850900e+04
# mean     3.177423e+06
# std      2.690026e+07
# min      1.000000e+00
# 25%      4.750000e+05
# 50%      7.980000e+05
# 75%      1.790000e+06
# max      2.397502e+09
# Name: SALE_PRICE, dtype: float64

# %%
fig, ax = plt.subplots()
ax.boxplot(df[df["SALE_PRICE"]>0]["SALE_PRICE"]);

# %% [markdown]
# We find the range of the 'SALE_PRICE' varies a lot.
# To wipe out unregular observation, We limit the price range from USD 100,000 to 100,000,000.
# which means, we exculde following percentage of data.

# %%
sum((df["SALE_PRICE"]<100000) | (df["SALE_PRICE"]>100000000))/len(df["SALE_PRICE"])
# Out:
# 0.030197634927779368

# %%
df[(df["SALE_PRICE"]>100000) & (df["SALE_PRICE"]<100000000)
  ]["SALE_PRICE"].plot.hist(bins=100);

# %% [markdown]
# Still, the range varies a lot. So we will take a log10.

# %%
df["SALE_PRICE"] = df["SALE_PRICE"].replace(0, np.NaN)
df["Logged_SALE_PRICE"] = df["SALE_PRICE"].apply(np.log10)

rows = 1
cols = 2
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(10*cols, 6*rows))
axs = axs.flatten()
axs[0].hist(df[(df["Logged_SALE_PRICE"]>5)]["Logged_SALE_PRICE"], bins=30);
axs[1].boxplot(df[(df["Logged_SALE_PRICE"]>5)]["Logged_SALE_PRICE"]);
plt.tight_layout()

# %% [markdown]
# So, it seems better than before. So, we will use our target value as Logged_SALE_PRICE.

# %% [markdown]
# ## Another transformation we will need

# %% [markdown]
# We have 'YEAR_BUILT' data which is a data when the building built.
#
# However, the data itself has no mean as we need the "AGE" of the building.
#
# So, we will create new variable called "AGE".

# %%
df["YEAR_BUILT"] = df["YEAR_BUILT"].replace(0, np.NaN)
df["SALE_DATE"] = df["SALE_DATE"].replace(0, np.NaN)
df["AGE"] = df["SALE_DATE"].dt.year - df["YEAR_BUILT"]
df["AGE"].head()
# Out:
# 0    158.0
# 1    158.0
# 2    118.0
# 3    119.0
# 4    118.0
# Name: AGE, dtype: float64

# %%
df["AGE"].hist(bins=20)

# %% [markdown]
# Also, the MONTH might be affect the value of the real estate if the other conditions hold:
#
# So, we will create new variable called "SALE MONTH".

# %%
df["SALE_MONTH"] = df["SALE_DATE"].dt.month.astype(int)

# %%
df.groupby("SALE_MONTH")["Logged_SALE_PRICE"].median().plot()
df.groupby("SALE_MONTH")["Logged_SALE_PRICE"].mean().plot()

# %% [markdown]
# ## Data Plot with Logged_SALE_PRICE

# %% [markdown]
# ### Categorical Variables and what they look like:

# %% [markdown]
# We select some variables

# %%
df=df[df["SALE_PRICE"]!=df["SALE_PRICE"].max()]

# %%
forboxplot = ['NEIGHBORHOOD','BUILDING_CLASS_CATEGORY','TAX_CLASS_AT_PRESENT', 'ZIP_CODE',"SALE_MONTH", 
              'TAX_CLASS_AT_TIME_OF_SALE', 'BUILDING_CLASS_AT_TIME_OF_SALE','AREA','not_apartment',]

rows = len(forboxplot)
cols = 2 
fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(8*cols, 5*rows))

j=0

for i in forboxplot:
    df.boxplot("Logged_SALE_PRICE", i, grid=False, sym='k.', ax=axes[j, 0])
    df.boxplot("SALE_PRICE", i, grid=False, sym='k.', ax=axes[j, 1])
    j += 1

# %%
rows = 1
cols = 3
fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(4*cols, 5*rows))
axs = axs.flatten()
j=0
features_selected = features_selected=['TOTAL_UNITS', 'GROSS_SQUARE_FEET','AGE']
for i in features_selected:
    axs[j].scatter(x=i, y="SALE_PRICE",data=df)
    j = j+1
plt.tight_layout()

# %%
rows = 1
cols = 3

fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(4*cols, 5*rows))
axs = axs.flatten()
j=0
features_selected = features_selected=['TOTAL_UNITS', 'GROSS_SQUARE_FEET','AGE']
for i in features_selected:
    axs[j].scatter(x=i, y="Logged_SALE_PRICE",data=df)
    j = j+1
plt.tight_layout()

# %%
df["Logged_TOTAL_UNITS"] = df["TOTAL_UNITS"].replace(0,np.NaN).apply(np.log10)
df["Logged_GROSS_SQUARE_FEET"] = df["GROSS_SQUARE_FEET"].replace(0,np.NaN).apply(np.log10)
df["Logged_AGE"] = df["AGE"].replace(0,np.NaN).apply(np.log10)

logged_features_selected=['Logged_TOTAL_UNITS', 'Logged_GROSS_SQUARE_FEET', 'Logged_AGE']


fig, axs = plt.subplots(ncols=cols, nrows=rows, figsize=(4*cols, 5*rows))
axs = axs.flatten()
j=0
for i in logged_features_selected:
    axs[j].scatter(x=i, y="Logged_SALE_PRICE",data=df)
    j = j+1
plt.tight_layout()

# %% [markdown]
# # Data Preparation
#
# We made the data understanding using only from Manhattan & Bronx.
#
# We use all the 2018 data from NYC.

# %%
df_mh=pd.read_excel("rollingsales_manhattan.xls",skiprows=4)
# df_mh.columns=df_mh.columns.str.replace(' ', '_')
df_mh.columns.tolist()
# Out:
# ['BOROUGH',
#  'NEIGHBORHOOD',
#  'BUILDING CLASS CATEGORY',
#  'TAX CLASS AT PRESENT',
#  'BLOCK',
#  'LOT',
#  'EASE-MENT',
#  'BUILDING CLASS AT PRESENT',
#  'ADDRESS',
#  'APARTMENT NUMBER',
#  'ZIP CODE',
#  'RESIDENTIAL UNITS',
#  'COMMERCIAL UNITS',
#  'TOTAL UNITS',
#  'LAND SQUARE FEET',
#  'GROSS SQUARE FEET',
#  'YEAR BUILT',
#  'TAX CLASS AT TIME OF SALE',
#  'BUILDING CLASS AT TIME OF SALE',
#  'SALE PRICE',
#  'SALE DATE']

# %%
def load_data():
#     col=['BOROUGH', 'BUILDING CLASS CATEGORY','TAX CLASS AT PRESENT','TAX CLASS AT TIME OF SALE','SALE PRICE']
    df_mh=pd.read_excel("rollingsales_manhattan.xls",skiprows=4)
#     df_mh=get_columns(df_mh,col)
    
    df_bk=pd.read_excel("rollingsales_brooklyn.xls",skiprows=4)
#     df_bk=get_columns(df_bk,col)
    
    df_bx=pd.read_excel("rollingsales_bronx.xls",skiprows=4)
#     df_bx=get_columns(df_bx,col)
    
    df_qs=pd.read_excel("rollingsales_queens.xls",skiprows=4)
#     df_qs=get_columns(df_qs,col)
    
    df_si=pd.read_excel("rollingsales_statenisland.xls",skiprows=4)
#     df_si=get_columns(df_si,col)
    
    df2018=pd.concat([df_mh,df_bk,df_bx,df_qs,df_si])
    
#     df_mh_17=pd.read_excel("2017_manhattan.xls",skiprows=4)
#     df_mh_17=get_columns(df_mh_17,col)
    
#     df_bk_17=pd.read_excel("2017_brooklyn.xls",skiprows=4)
#     df_bk_17=get_columns(df_bk_17,col)
    
#     df_bx_17=pd.read_excel("2017_bronx.xls",skiprows=4)
#     df_bx_17=get_columns(df_bx_17,col)
    
#     df_qs_17=pd.read_excel("2017_queens.xls",skiprows=4)
#     df_qs_17=get_columns(df_qs_17,col)
    
#     df_si_17=pd.read_excel("2017_statenisland.xls",skiprows=4)
#     df_si_17=get_columns(df_si_17,col)
    
#     df=pd.concat([df2018,df_mh_17,df_bk_17,df_bx_17,df_qs_17,df_si_17])
    df=df2018
    df=df.drop('EASE-MENT', 1)
    df=df.drop('APARTMENT NUMBER', 1)
    df=df.dropna()
    df.columns = df.columns.str.replace(' ', '_')
    return df

# %%
df=load_data()

# %% [markdown]
# Then, we make the data clean:

# %%
df = df[df["SALE_PRICE"]!=0]

# %%
df["SALE_PRICE"] = df["SALE_PRICE"].replace(0, np.NaN)
df["YEAR_BUILT"] = df["YEAR_BUILT"].replace(0, np.NaN)
df["SALE_DATE"] = df["SALE_DATE"].replace(0, np.NaN)
df["SALE_MONTH"] = df["SALE_DATE"].dt.month.astype(int)

# %% [markdown]
# Then, we create some variables such as:
# 'SALE_MONTH', 'Logged_SALE_PRICE', 'AGE', 'Logged_TOTAL_UNITS', 'Logged_GROSS_SQUARE_FEET', 'Logged_AGE,

# %%
df["Logged_SALE_PRICE"] = df["SALE_PRICE"].apply(np.log10)
df["AGE"] = df["SALE_DATE"].dt.year - df["YEAR_BUILT"]
df["Logged_TOTAL_UNITS"] = df["TOTAL_UNITS"].replace(0,np.NaN).apply(np.log10)
df["Logged_GROSS_SQUARE_FEET"] = df["GROSS_SQUARE_FEET"].replace(0,np.NaN).apply(np.log10)
df["Logged_AGE"] = df["AGE"].replace(0,np.NaN).apply(np.log10)
df=df[df["Logged_SALE_PRICE"]!=0]

# %% [markdown]
# Now, we have following data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56832 entries, 0 to 8384
# Data columns (total 25 columns):
# BOROUGH                           56832 non-null int64
# NEIGHBORHOOD                      56832 non-null object
# BUILDING_CLASS_CATEGORY           56832 non-null object
# TAX_CLASS_AT_PRESENT              56832 non-null object
# BLOCK                             56832 non-null int64
# LOT                               56832 non-null int64
# BUILDING_CLASS_AT_PRESENT         56832 non-null object
# ADDRESS                           56832 non-null object
# ZIP_CODE                          56832 non-null float64
# RESIDENTIAL_UNITS                 56832 non-null float64
# COMMERCIAL_UNITS                  56832 non-null float64
# TOTAL_UNITS                       56832 non-null float64
# LAND_SQUARE_FEET                  56832 non-null float64
# GROSS_SQUARE_FEET                 56832 non-null float64
# YEAR_BUILT                        53240 non-null float64
# TAX_CLASS_AT_TIME_OF_SALE         56832 non-null int64
# BUILDING_CLASS_AT_TIME_OF_SALE    56832 non-null object
# SALE_PRICE                        56832 non-null int64
# SALE_DATE                         56832 non-null datetime64[ns]
# SALE_MONTH                        56832 non-null int32
# Logged_SALE_PRICE                 56832 non-null float64
# AGE                               53240 non-null float64
# Logged_TOTAL_UNITS                41643 non-null float64
# Logged_GROSS_SQUARE_FEET          41085 non-null float64
# Logged_AGE                        53063 non-null float64
# dtypes: datetime64[ns](1), float64(12), int32(1), int64(5), object(6)
# memory usage: 11.1+ MB

# %%
df = df.dropna()

# %% [markdown]
# # Modeling

# %% [markdown]
# We will make an Regression, first Target Variables = SALE_PRICE (Not SALE_PRICE)

# %%
def selec_features(features):
    df_select=df[features]
    df_select=df_select[df_select['SALE_PRICE']>10000]
    X = df_select.drop(['SALE_PRICE'], axis=1)
    Y = df_select['SALE_PRICE']
    return X,Y

# %%
# select neighborhood / BLOCK + GROSS_SQUARE_FEET
features_selected=[
 'BOROUGH',
#  'NEIGHBORHOOD',
 'BUILDING_CLASS_CATEGORY',
 'TAX_CLASS_AT_PRESENT',
 'BLOCK',
 'LOT',
#  'BUILDING_CLASS_AT_PRESENT',
#  'ADDRESS',
#  'APARTMENT_NUMBER',
# 'ZIP_CODE',
 'RESIDENTIAL_UNITS',
 'COMMERCIAL_UNITS',
 'TOTAL_UNITS',
 'LAND_SQUARE_FEET',
 'GROSS_SQUARE_FEET',
 'YEAR_BUILT',
 'TAX_CLASS_AT_TIME_OF_SALE',
#  'BUILDING_CLASS_AT_TIME_OF_SALE',
 'SALE_PRICE',
# 'SALE_MONTH', 
# 'Logged_SALE_PRICE', 
# 'AGE',
# 'Logged_TOTAL_UNITS', 
# 'Logged_GROSS_SQUARE_FEET',
# 'Logged_AGE'
]
# features_selected=['BLOCK','GROSS_SQUARE_FEET','SALE_PRICE']

X, Y = selec_features(features_selected)
X = pd.get_dummies(X, columns=['BOROUGH','BUILDING_CLASS_CATEGORY','TAX_CLASS_AT_PRESENT','TAX_CLASS_AT_TIME_OF_SALE'])
# X=pd.get_dummies(X, columns=['BLOCK'])
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37303 entries, 0 to 8380
# Data columns (total 58 columns):
# BLOCK                                                                 37303 non-null int64
# LOT                                                                   37303 non-null int64
# RESIDENTIAL_UNITS                                                     37303 non-null float64
# COMMERCIAL_UNITS                                                      37303 non-null float64
# TOTAL_UNITS                                                           37303 non-null float64
# LAND_SQUARE_FEET                                                      37303 non-null float64
# GROSS_SQUARE_FEET                                                     37303 non-null float64
# YEAR_BUILT                                                            37303 non-null float64
# BOROUGH_1                                                             37303 non-null uint8
# BOROUGH_2                                                             37303 non-null uint8
# BOROUGH_3                                                             37303 non-null uint8
# BOROUGH_4                                                             37303 non-null uint8
# BOROUGH_5                                                             37303 non-null uint8
# BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS                       37303 non-null uint8
# BUILDING_CLASS_CATEGORY_02 TWO FAMILY DWELLINGS                       37303 non-null uint8
# BUILDING_CLASS_CATEGORY_03 THREE FAMILY DWELLINGS                     37303 non-null uint8
# BUILDING_CLASS_CATEGORY_04 TAX CLASS 1 CONDOS                         37303 non-null uint8
# BUILDING_CLASS_CATEGORY_07 RENTALS - WALKUP APARTMENTS                37303 non-null uint8
# BUILDING_CLASS_CATEGORY_08 RENTALS - ELEVATOR APARTMENTS              37303 non-null uint8
# BUILDING_CLASS_CATEGORY_11A CONDO-RENTALS                             37303 non-null uint8
# BUILDING_CLASS_CATEGORY_12 CONDOS - WALKUP APARTMENTS                 37303 non-null uint8
# BUILDING_CLASS_CATEGORY_13 CONDOS - ELEVATOR APARTMENTS               37303 non-null uint8
# BUILDING_CLASS_CATEGORY_14 RENTALS - 4-10 UNIT                        37303 non-null uint8
# BUILDING_CLASS_CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL             37303 non-null uint8
# BUILDING_CLASS_CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT    37303 non-null uint8
# BUILDING_CLASS_CATEGORY_21 OFFICE BUILDINGS                           37303 non-null uint8
# BUILDING_CLASS_CATEGORY_22 STORE BUILDINGS                            37303 non-null uint8
# BUILDING_CLASS_CATEGORY_23 LOFT BUILDINGS                             37303 non-null uint8
# BUILDING_CLASS_CATEGORY_25 LUXURY HOTELS                              37303 non-null uint8
# BUILDING_CLASS_CATEGORY_26 OTHER HOTELS                               37303 non-null uint8
# BUILDING_CLASS_CATEGORY_27 FACTORIES                                  37303 non-null uint8
# BUILDING_CLASS_CATEGORY_29 COMMERCIAL GARAGES                         37303 non-null uint8
# BUILDING_CLASS_CATEGORY_30 WAREHOUSES                                 37303 non-null uint8
# BUILDING_CLASS_CATEGORY_32 HOSPITAL AND HEALTH FACILITIES             37303 non-null uint8
# BUILDING_CLASS_CATEGORY_33 EDUCATIONAL FACILITIES                     37303 non-null uint8
# BUILDING_CLASS_CATEGORY_34 THEATRES                                   37303 non-null uint8
# BUILDING_CLASS_CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES      37303 non-null uint8
# BUILDING_CLASS_CATEGORY_36 OUTDOOR RECREATIONAL FACILITIES            37303 non-null uint8
# BUILDING_CLASS_CATEGORY_37 RELIGIOUS FACILITIES                       37303 non-null uint8
# BUILDING_CLASS_CATEGORY_38 ASYLUMS AND HOMES                          37303 non-null uint8
# BUILDING_CLASS_CATEGORY_39 TRANSPORTATION FACILITIES                  37303 non-null uint8
# BUILDING_CLASS_CATEGORY_41 TAX CLASS 4 - OTHER                        37303 non-null uint8
# BUILDING_CLASS_CATEGORY_42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC     37303 non-null uint8
# BUILDING_CLASS_CATEGORY_43 CONDO OFFICE BUILDINGS                     37303 non-null uint8
# BUILDING_CLASS_CATEGORY_44 CONDO PARKING                              37303 non-null uint8
# BUILDING_CLASS_CATEGORY_45 CONDO HOTELS                               37303 non-null uint8
# BUILDING_CLASS_CATEGORY_46 CONDO STORE BUILDINGS                      37303 non-null uint8
# TAX_CLASS_AT_PRESENT_1                                                37303 non-null uint8
# TAX_CLASS_AT_PRESENT_2                                                37303 non-null uint8
# TAX_CLASS_AT_PRESENT_4                                                37303 non-null uint8
# TAX_CLASS_AT_PRESENT_1A                                               37303 non-null uint8
# TAX_CLASS_AT_PRESENT_1C                                               37303 non-null uint8
# TAX_CLASS_AT_PRESENT_2A                                               37303 non-null uint8
# TAX_CLASS_AT_PRESENT_2B                                               37303 non-null uint8
# TAX_CLASS_AT_PRESENT_2C                                               37303 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_1                                           37303 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_2                                           37303 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_4                                           37303 non-null uint8
# dtypes: float64(6), int64(2), uint8(50)
# memory usage: 4.3 MB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.25)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

# def rmse(y_test,y_pred):
#       return np.sqrt(mean_squared_error(y_test,y_pred))

def model_score(model):
    model=model
    model.fit(X_train, Y_train)
    Y_pred=model.predict(X_test)
    score=model.score(X_test, Y_test)
#     rmse=rmse(Y_test,Y_pred)
    return score

# %%
model=RandomForestRegressor(max_depth=50)
print("features_selected:", features_selected)
print("RandomForestRegressor:"+str(model_score(model)))
s = cross_val_score(model, X_train,Y_train, cv=10).mean()
print("cross_val_score",s)
# Out:
# features_selected: ['BOROUGH', 'BUILDING_CLASS_CATEGORY', 'TAX_CLASS_AT_PRESENT', 'BLOCK', 'LOT', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET', 'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE', 'SALE_PRICE']
# C:\Users\ryouen\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor:0.5410085607475548
# cross_val_score 0.5628908486834062

# %%
model=GradientBoostingRegressor(max_depth=6,learning_rate=0.05,n_estimators=500)
print("features_selected:", features_selected)
score=model_score(model)
print("GradientBoostingRegressor:"+str(score))
importance = model.feature_importances_
importance.argsort()
# Out:
# features_selected: ['BOROUGH', 'BUILDING_CLASS_CATEGORY', 'TAX_CLASS_AT_PRESENT', 'BLOCK', 'LOT', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET', 'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE', 'SALE_PRICE']
# GradientBoostingRegressor:0.5474597346970513
# array([51, 24, 40, 16, 15, 50, 36, 14, 20, 52, 55, 42, 39, 47, 22, 37, 30,
#        53, 34, 23, 13, 38, 54, 41, 32, 33,  9, 29, 45, 12, 46, 27, 11, 31,
#        44, 49, 18, 10, 19, 57, 56, 43, 17, 48, 25,  2,  8, 21,  4,  3,  1,
#        26, 28,  5,  7,  0, 35,  6], dtype=int64)

# %%
importance = model.feature_importances_
importance.argsort()
# Out:
# array([51, 24, 40, 16, 15, 50, 36, 14, 20, 52, 55, 42, 39, 47, 22, 37, 30,
#        53, 34, 23, 13, 38, 54, 41, 32, 33,  9, 29, 45, 12, 46, 27, 11, 31,
#        44, 49, 18, 10, 19, 57, 56, 43, 17, 48, 25,  2,  8, 21,  4,  3,  1,
#        26, 28,  5,  7,  0, 35,  6], dtype=int64)

# %% [markdown]
# # Next, Target Variables = "Logged_SALE_PRICE"

# %%
def selec_features(features):
    df_select=df[features]
    df_select=df_select[df_select['Logged_SALE_PRICE']>5]
    X = df_select.drop(['Logged_SALE_PRICE'], axis=1)
    Y = df_select['Logged_SALE_PRICE']
    return X,Y

# select neighborhood / BLOCK + GROSS_SQUARE_FEET
features_selected=[
 'BOROUGH',
#  'NEIGHBORHOOD',
 'BUILDING_CLASS_CATEGORY',
 'TAX_CLASS_AT_PRESENT',
 'BLOCK',
 'LOT',
#  'BUILDING_CLASS_AT_PRESENT',
#  'ADDRESS',
#  'APARTMENT_NUMBER',
# 'ZIP_CODE',
 'RESIDENTIAL_UNITS',
 'COMMERCIAL_UNITS',
 'TOTAL_UNITS',
 'LAND_SQUARE_FEET',
 'GROSS_SQUARE_FEET',
 'YEAR_BUILT',
 'TAX_CLASS_AT_TIME_OF_SALE',
#  'BUILDING_CLASS_AT_TIME_OF_SALE',
# 'SALE_PRICE',
# 'SALE_MONTH', 
 'Logged_SALE_PRICE', 
 'AGE',
 'Logged_TOTAL_UNITS', 
 'Logged_GROSS_SQUARE_FEET',
 'Logged_AGE'
]

X, Y = selec_features(features_selected)
X = pd.get_dummies(X, columns=['BOROUGH','BUILDING_CLASS_CATEGORY','TAX_CLASS_AT_PRESENT','TAX_CLASS_AT_TIME_OF_SALE'])
# X=pd.get_dummies(X, columns=['BLOCK'])
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36834 entries, 0 to 8380
# Data columns (total 62 columns):
# BLOCK                                                                 36834 non-null int64
# LOT                                                                   36834 non-null int64
# RESIDENTIAL_UNITS                                                     36834 non-null float64
# COMMERCIAL_UNITS                                                      36834 non-null float64
# TOTAL_UNITS                                                           36834 non-null float64
# LAND_SQUARE_FEET                                                      36834 non-null float64
# GROSS_SQUARE_FEET                                                     36834 non-null float64
# YEAR_BUILT                                                            36834 non-null float64
# AGE                                                                   36834 non-null float64
# Logged_TOTAL_UNITS                                                    36834 non-null float64
# Logged_GROSS_SQUARE_FEET                                              36834 non-null float64
# Logged_AGE                                                            36834 non-null float64
# BOROUGH_1                                                             36834 non-null uint8
# BOROUGH_2                                                             36834 non-null uint8
# BOROUGH_3                                                             36834 non-null uint8
# BOROUGH_4                                                             36834 non-null uint8
# BOROUGH_5                                                             36834 non-null uint8
# BUILDING_CLASS_CATEGORY_01 ONE FAMILY DWELLINGS                       36834 non-null uint8
# BUILDING_CLASS_CATEGORY_02 TWO FAMILY DWELLINGS                       36834 non-null uint8
# BUILDING_CLASS_CATEGORY_03 THREE FAMILY DWELLINGS                     36834 non-null uint8
# BUILDING_CLASS_CATEGORY_04 TAX CLASS 1 CONDOS                         36834 non-null uint8
# BUILDING_CLASS_CATEGORY_07 RENTALS - WALKUP APARTMENTS                36834 non-null uint8
# BUILDING_CLASS_CATEGORY_08 RENTALS - ELEVATOR APARTMENTS              36834 non-null uint8
# BUILDING_CLASS_CATEGORY_11A CONDO-RENTALS                             36834 non-null uint8
# BUILDING_CLASS_CATEGORY_12 CONDOS - WALKUP APARTMENTS                 36834 non-null uint8
# BUILDING_CLASS_CATEGORY_13 CONDOS - ELEVATOR APARTMENTS               36834 non-null uint8
# BUILDING_CLASS_CATEGORY_14 RENTALS - 4-10 UNIT                        36834 non-null uint8
# BUILDING_CLASS_CATEGORY_15 CONDOS - 2-10 UNIT RESIDENTIAL             36834 non-null uint8
# BUILDING_CLASS_CATEGORY_16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT    36834 non-null uint8
# BUILDING_CLASS_CATEGORY_21 OFFICE BUILDINGS                           36834 non-null uint8
# BUILDING_CLASS_CATEGORY_22 STORE BUILDINGS                            36834 non-null uint8
# BUILDING_CLASS_CATEGORY_23 LOFT BUILDINGS                             36834 non-null uint8
# BUILDING_CLASS_CATEGORY_25 LUXURY HOTELS                              36834 non-null uint8
# BUILDING_CLASS_CATEGORY_26 OTHER HOTELS                               36834 non-null uint8
# BUILDING_CLASS_CATEGORY_27 FACTORIES                                  36834 non-null uint8
# BUILDING_CLASS_CATEGORY_29 COMMERCIAL GARAGES                         36834 non-null uint8
# BUILDING_CLASS_CATEGORY_30 WAREHOUSES                                 36834 non-null uint8
# BUILDING_CLASS_CATEGORY_32 HOSPITAL AND HEALTH FACILITIES             36834 non-null uint8
# BUILDING_CLASS_CATEGORY_33 EDUCATIONAL FACILITIES                     36834 non-null uint8
# BUILDING_CLASS_CATEGORY_34 THEATRES                                   36834 non-null uint8
# BUILDING_CLASS_CATEGORY_35 INDOOR PUBLIC AND CULTURAL FACILITIES      36834 non-null uint8
# BUILDING_CLASS_CATEGORY_36 OUTDOOR RECREATIONAL FACILITIES            36834 non-null uint8
# BUILDING_CLASS_CATEGORY_37 RELIGIOUS FACILITIES                       36834 non-null uint8
# BUILDING_CLASS_CATEGORY_38 ASYLUMS AND HOMES                          36834 non-null uint8
# BUILDING_CLASS_CATEGORY_39 TRANSPORTATION FACILITIES                  36834 non-null uint8
# BUILDING_CLASS_CATEGORY_41 TAX CLASS 4 - OTHER                        36834 non-null uint8
# BUILDING_CLASS_CATEGORY_42 CONDO CULTURAL/MEDICAL/EDUCATIONAL/ETC     36834 non-null uint8
# BUILDING_CLASS_CATEGORY_43 CONDO OFFICE BUILDINGS                     36834 non-null uint8
# BUILDING_CLASS_CATEGORY_44 CONDO PARKING                              36834 non-null uint8
# BUILDING_CLASS_CATEGORY_45 CONDO HOTELS                               36834 non-null uint8
# BUILDING_CLASS_CATEGORY_46 CONDO STORE BUILDINGS                      36834 non-null uint8
# TAX_CLASS_AT_PRESENT_1                                                36834 non-null uint8
# TAX_CLASS_AT_PRESENT_2                                                36834 non-null uint8
# TAX_CLASS_AT_PRESENT_4                                                36834 non-null uint8
# TAX_CLASS_AT_PRESENT_1A                                               36834 non-null uint8
# TAX_CLASS_AT_PRESENT_1C                                               36834 non-null uint8
# TAX_CLASS_AT_PRESENT_2A                                               36834 non-null uint8
# TAX_CLASS_AT_PRESENT_2B                                               36834 non-null uint8
# TAX_CLASS_AT_PRESENT_2C                                               36834 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_1                                           36834 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_2                                           36834 non-null uint8
# TAX_CLASS_AT_TIME_OF_SALE_4                                           36834 non-null uint8
# dtypes: float64(10), int64(2), uint8(50)
# memory usage: 5.4 MB

# %%
model=RandomForestRegressor(max_depth=50)
print("features_selected:", features_selected)
print("RandomForestRegressor:"+str(model_score(model)))
s = cross_val_score(model, X_train,Y_train, cv=10).mean()
print("cross_val_score",s)
# Out:
# features_selected: ['BOROUGH', 'BUILDING_CLASS_CATEGORY', 'TAX_CLASS_AT_PRESENT', 'BLOCK', 'LOT', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET', 'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE', 'Logged_SALE_PRICE', 'AGE', 'Logged_TOTAL_UNITS', 'Logged_GROSS_SQUARE_FEET', 'Logged_AGE']
# C:\Users\ryouen\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor:0.5123779836637676
# cross_val_score 0.367881760999072

# %%
model=GradientBoostingRegressor(max_depth=6,learning_rate=0.05,n_estimators=500)
print("features_selected:", features_selected)
score=model_score(model)
print("GradientBoostingRegressor:"+str(score))
importance = model.feature_importances_
importance.argsort()
# Out:
# features_selected: ['BOROUGH', 'BUILDING_CLASS_CATEGORY', 'TAX_CLASS_AT_PRESENT', 'BLOCK', 'LOT', 'RESIDENTIAL_UNITS', 'COMMERCIAL_UNITS', 'TOTAL_UNITS', 'LAND_SQUARE_FEET', 'GROSS_SQUARE_FEET', 'YEAR_BUILT', 'TAX_CLASS_AT_TIME_OF_SALE', 'Logged_SALE_PRICE', 'AGE', 'Logged_TOTAL_UNITS', 'Logged_GROSS_SQUARE_FEET', 'Logged_AGE']
# GradientBoostingRegressor:0.571176519590729
# array([24, 16, 51, 40, 50, 36, 15, 20, 14, 55, 52, 54, 47, 42, 22, 37, 30,
#        39, 53, 29, 38, 34, 13, 41, 32, 33, 23,  9, 45, 12, 46, 27, 44, 31,
#        19, 57, 18, 49, 10, 43, 56, 17, 48, 11, 25,  2,  8, 21,  4, 26,  3,
#         1, 28,  5,  0,  7, 35,  6], dtype=int64)
